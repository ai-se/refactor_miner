# %%
from refactoring_getter import refactormine
from metrics_getter import git_understand
from utils import regex_matcher
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import linear_model
from sklearn import metrics


import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/suvodeepmajumder/Documents/AI4SE/refactor_miner/results/understand/xerces2.csv')
df1 = df[df['Refactoring_type'].isin([#'Move Attribute',
                                      #'Extract And Move Method',
                                      'Extract Method',
                                      #'Move Class',
                                      #'Move Method',
                                      #'Pull Up Attribute',
                                      #'Pull Up Method',
                                      #'Push Down Attribute',
                                      #'Rename Method',
                                      #'Push Down Method'
                                     ])]
#df1 = df[df['Refactoring_type'] =='Move Method']
df1 = df1.drop_duplicates(subset = ['AvgCyclomatic', 'AvgCyclomaticModified', 'AvgCyclomaticStrict',
       'AvgEssential', 'AvgLine', 'AvgLineBlank', 'AvgLineCode',
       'AvgLineComment', 'Commit_hash', 'CountClassBase', 'CountClassCoupled',
       'CountClassDerived', 'CountDeclClassMethod', 'CountDeclClassVariable',
       'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
       'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
       'CountDeclMethodPrivate', 'CountDeclMethodProtected',
       'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
       'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
       'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
       'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
       'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
       'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
       'RatioCommentToCode', 'SumCyclomatic',
       'SumCyclomaticModified', 'SumCyclomaticStrict', 'SumEssential'],keep=False)
y = df1.Refactored
X = df1.drop(labels=['Name','Type','Refactored','Refactoring_type','Commit_hash'],axis=1)
train_X,test_X,train_y,test_y = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = LogisticRegression(penalty='l1',class_weight='balanced')
clf.fit(train_X,train_y)
predicted = clf.predict(test_X)
fpr, tpr, thresholds = metrics.roc_curve(test_y, predicted, pos_label=1)
print(metrics.auc(fpr, tpr))
print(classification_report(test_y, predicted))
print(clf.coef_)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.40148171500630514
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.44      0.40        52
#          1.0       0.43      0.36      0.39        61
#
#    micro avg       0.40      0.40      0.40       113
#    macro avg       0.40      0.40      0.40       113
# weighted avg       0.40      0.40      0.40       113
#
# [[-8.02803503e-01  0.00000000e+00  4.13963996e-01  0.00000000e+00
#    1.02428359e-01  3.82181674e-02  1.08160521e-02 -1.21883194e-01
#    1.29461164e-01 -2.67671386e-02  0.00000000e+00  3.34556932e-02
#    2.96202640e-03 -9.18070358e-03  1.06996029e-02  0.00000000e+00
#    6.06502707e-03 -2.96968320e-02 -5.44620299e-02  1.76420429e-02
#    2.24458159e-03 -1.73061985e-05 -5.29105021e-03 -2.25487199e-03
#   -8.26403798e-03  2.73467859e-03  4.88993861e-04 -1.12579962e-02
#    3.59031357e-03  2.37905097e-02  1.65839815e-03  0.00000000e+00
#    5.41719626e-02 -4.94107305e-02  2.39123219e-02 -1.21450081e-01
#   -2.21848038e-01 -1.34317510e-02  8.31045298e-03  3.82222847e-01
#    2.79722718e-02 -1.38342837e-02 -4.15502088e-03 -6.31275541e-03]]
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
df.groupby('Refactoring_type').count()
# Out:
#                          AvgCyclomatic  AvgCyclomaticModified  \
# Refactoring_type
# Extract And Move Method             73                     73
# Extract Method                     344                    344
# Inline Method                       78                     78
# Move Attribute                     202                    202
# Move Class                         219                    219
# Move Method                         47                     47
# Pull Up Attribute                  131                    131
# Pull Up Method                      38                     38
# Push Down Attribute                 43                     43
# Push Down Method                     8                      8
# Rename Class                        56                     56
# Rename Method                      328                    328
#
#                          AvgCyclomaticStrict  AvgEssential  AvgLine  \
# Refactoring_type
# Extract And Move Method                   73            73       73
# Extract Method                           344           344      344
# Inline Method                             78            78       78
# Move Attribute                           202           202      202
# Move Class                               219           219      219
# Move Method                               47            47       47
# Pull Up Attribute                        131           131      131
# Pull Up Method                            38            38       38
# Push Down Attribute                       43            43       43
# Push Down Method                           8             8        8
# Rename Class                              56            56       56
# Rename Method                            328           328      328
#
#                          AvgLineBlank  AvgLineCode  AvgLineComment  \
# Refactoring_type
# Extract And Move Method            73           73              73
# Extract Method                    344          344             344
# Inline Method                      78           78              78
# Move Attribute                    202          202             202
# Move Class                        219          219             219
# Move Method                        47           47              47
# Pull Up Attribute                 131          131             131
# Pull Up Method                     38           38              38
# Push Down Attribute                43           43              43
# Push Down Method                    8            8               8
# Rename Class                       56           56              56
# Rename Method                     328          328             328
#
#                          Commit_hash  CountClassBase  ...  Name  \
# Refactoring_type                                      ...
# Extract And Move Method           73              73  ...    73
# Extract Method                   344             344  ...   344
# Inline Method                     78              78  ...    78
# Move Attribute                   202             202  ...   202
# Move Class                       227             219  ...   227
# Move Method                       47              47  ...    47
# Pull Up Attribute                132             131  ...   132
# Pull Up Method                    38              38  ...    38
# Push Down Attribute               43              43  ...    43
# Push Down Method                   8               8  ...     8
# Rename Class                      63              56  ...    63
# Rename Method                    328             328  ...   328
#
#                          PercentLackOfCohesion  PercentLackOfCohesionModified  \
# Refactoring_type
# Extract And Move Method                     73                             73
# Extract Method                             344                            344
# Inline Method                               78                             78
# Move Attribute                             202                            202
# Move Class                                 219                            219
# Move Method                                 47                             47
# Pull Up Attribute                          131                            131
# Pull Up Method                              38                             38
# Push Down Attribute                         43                             43
# Push Down Method                             8                              8
# Rename Class                                56                             56
# Rename Method                              328                            328
#
#                          RatioCommentToCode  Refactored  SumCyclomatic  \
# Refactoring_type
# Extract And Move Method                  73          73             73
# Extract Method                          344         344            344
# Inline Method                            78          78             78
# Move Attribute                          202         202            202
# Move Class                              219         227            219
# Move Method                              47          47             47
# Pull Up Attribute                       131         132            131
# Pull Up Method                           38          38             38
# Push Down Attribute                      43          43             43
# Push Down Method                          8           8              8
# Rename Class                             56          63             56
# Rename Method                           328         328            328
#
#                          SumCyclomaticModified  SumCyclomaticStrict  \
# Refactoring_type
# Extract And Move Method                     73                   73
# Extract Method                             344                  344
# Inline Method                               78                   78
# Move Attribute                             202                  202
# Move Class                                 219                  219
# Move Method                                 47                   47
# Pull Up Attribute                          131                  131
# Pull Up Method                              38                   38
# Push Down Attribute                         43                   43
# Push Down Method                             8                    8
# Rename Class                                56                   56
# Rename Method                              328                  328
#
#                          SumEssential  Type
# Refactoring_type
# Extract And Move Method            73    73
# Extract Method                    344   344
# Inline Method                      78    78
# Move Attribute                    202   202
# Move Class                        219   227
# Move Method                        47    47
# Pull Up Attribute                 131   132
# Pull Up Method                     38    38
# Push Down Attribute                43    43
# Push Down Method                    8     8
# Rename Class                       56    63
# Rename Method                     328   328
#
# [12 rows x 48 columns]
