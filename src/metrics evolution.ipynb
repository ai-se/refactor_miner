# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-95-208755c72149> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from rpy2.robjects import r, pandas2ri
#       4
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'rpy2'

# %%
df = pd.read_csv('/Users/suvodeepmajumder/Documents/AI4SE/refactor_miner/results/refactored_freq/ant.csv')

# %%
df.groupby(['Name','Refactoring_type']).count().sort_values(by=['AvgCyclomatic'],axis = 0, ascending = False)
# Out:
#                                                                        AvgCyclomatic  \
# Name                                               Refactoring_type
# org.apache.tools.ant.Project                       Extract Method                 70
# org.apache.tools.ant.util.FileUtils                Extract Method                 50
# org.apache.tools.ant.DirectoryScanner              Extract Method                 36
# org.apache.tools.ant.taskdefs.Zip                  Extract Method                 36
# org.apache.tools.ant.taskdefs.optional.junit.JU... Extract Method                 22
# org.apache.tools.ant.Project                       Move Attribute                 20
# org.apache.tools.ant.taskdefs.compilers.Default... Extract Method                 18
# org.apache.tools.ant.Project                       Rename Method                  18
#                                                    Inline Method                  18
# ...

# %%
df1 = df[df['Name'] == 'org.apache.tools.ant.util.FileUtils']

# %%
df1 = df1.sort_values(by=['commit_time'],axis = 0)

# %%
df1.columns
# Out:
# Index(['AvgCyclomatic', 'AvgCyclomaticModified', 'AvgCyclomaticStrict',
#        'AvgEssential', 'AvgLine', 'AvgLineBlank', 'AvgLineCode',
#        'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassDerived', 'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
# ...

# %%
X1 = df1[df1['Refactored'] == 0].PercentLackOfCohesion.values
X2 = df1[df1['Refactored'] == 1].PercentLackOfCohesion.values

plt.plot(X1,marker='o', color='b')
plt.plot(X2,marker='o', color='r')

# %%
x = df.sep_count.values
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x126febef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x126ff5860>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x126febda0>],
#  'medians': [<matplotlib.lines.Line2D at 0x126ff5ef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x126ff5fd0>],
#  'means': []}

# %%
y = df.change_size.values
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x127085fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1270feb70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1270fe0f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1270fef98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x127107588>],
#  'means': []}

# %%
x = df.sep_count.values
y = df.change_size.values
plt.scatter(x,y)
